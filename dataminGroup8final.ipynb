# %% [markdown]
# # Speed Dating
# this dataset comes from https://www.kaggle.com/datasets/ulrikthygepedersen/speed-dating
#  A series of 21 speed-dating events, and data was collected about participants before and during the event. The dataset includes information about participants' age, gender, race, attributes, priorities, interests, and reactions to one another.

# %% [markdown]
# REFERENCE : https://www.kaggle.com/code/nyagami/dimension-reduction-on-the-speed-dating-dataset

# %% [markdown]
# ### 1. Import libraries

# %%
import pandas as pd
import numpy as np

# Modeling
from sklearn.decomposition import PCA
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.impute import SimpleImputer
from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFE
from sklearn import tree
from sklearn.metrics import accuracy_score, f1_score, roc_auc_score, recall_score,precision_score,balanced_accuracy_score
import missingno
import xgboost as xgb

#data sampling : deal with imbalance data
from imblearn.under_sampling import RandomUnderSampler

# Datavisualiztion
import matplotlib.pyplot as plt
import seaborn as sns

### Remove unnecessary warnings
import warnings
warnings.filterwarnings('ignore')
RANDOM_SEED = 42

import re

# %% [markdown]
# ### 2. Import Data
#  records = 8378  and column = 123

# %%
dating = pd.read_csv("C:/Users/admin/Downloads/3 year/data mining/projectspeeddating/dataraw/speeddating.csv")
print('Data size: ',dating.shape)
# Out:
# Data size:  (8378, 123)

# %%
pd.set_option('display.max_columns', None)  # to see all column
dating.head(10)
# Out:
#   has_null  wave     gender   age  age_o  d_age    d_d_age  \
# 0      b''   1.0  b'female'  21.0   27.0    6.0   b'[4-6]'
# 1      b''   1.0  b'female'  21.0   22.0    1.0   b'[0-1]'
# 2      b''   1.0  b'female'  21.0   22.0    1.0   b'[0-1]'
# 3      b''   1.0  b'female'  21.0   23.0    2.0   b'[2-3]'
# 4      b''   1.0  b'female'  21.0   24.0    3.0   b'[2-3]'
# 5      b''   1.0  b'female'  21.0   25.0    4.0   b'[4-6]'
# 6      b''   1.0  b'female'  21.0   30.0    9.0  b'[7-37]'
# 7      b''   1.0  b'female'  21.0   27.0    6.0   b'[4-6]'
# 8      b''   1.0  b'female'  21.0   28.0    7.0  b'[7-37]'
# 9      b''   1.0  b'female'  21.0   24.0    3.0   b'[2-3]'
#
#                                        race  \
# 0  b'Asian/Pacific Islander/Asian-American'
# 1  b'Asian/Pacific Islander/Asian-American'
# 2  b'Asian/Pacific Islander/Asian-American'
# 3  b'Asian/Pacific Islander/Asian-American'
# 4  b'Asian/Pacific Islander/Asian-American'
# 5  b'Asian/Pacific Islander/Asian-American'
# 6  b'Asian/Pacific Islander/Asian-American'
# 7  b'Asian/Pacific Islander/Asian-American'
# 8  b'Asian/Pacific Islander/Asian-American'
# 9  b'Asian/Pacific Islander/Asian-American'
#
#                                      race_o samerace  importance_same_race  \
# 0            b'European/Caucasian-American'     b'0'                   2.0
# 1            b'European/Caucasian-American'     b'0'                   2.0
# 2  b'Asian/Pacific Islander/Asian-American'     b'1'                   2.0
# 3            b'European/Caucasian-American'     b'0'                   2.0
# 4               b'Latino/Hispanic American'     b'0'                   2.0
# 5            b'European/Caucasian-American'     b'0'                   2.0
# 6            b'European/Caucasian-American'     b'0'                   2.0
# 7            b'European/Caucasian-American'     b'0'                   2.0
# 8            b'European/Caucasian-American'     b'0'                   2.0
# 9            b'European/Caucasian-American'     b'0'                   2.0
#
#    importance_same_religion d_importance_same_race d_importance_same_religion  \
# 0                       4.0               b'[2-5]'                   b'[2-5]'
# 1                       4.0               b'[2-5]'                   b'[2-5]'
# 2                       4.0               b'[2-5]'                   b'[2-5]'
# 3                       4.0               b'[2-5]'                   b'[2-5]'
# 4                       4.0               b'[2-5]'                   b'[2-5]'
# 5                       4.0               b'[2-5]'                   b'[2-5]'
# 6                       4.0               b'[2-5]'                   b'[2-5]'
# 7                       4.0               b'[2-5]'                   b'[2-5]'
# 8                       4.0               b'[2-5]'                   b'[2-5]'
# 9                       4.0               b'[2-5]'                   b'[2-5]'
#
#     field  pref_o_attractive  pref_o_sincere  pref_o_intelligence  \
# 0  b'Law'              35.00           20.00                20.00
# 1  b'Law'              60.00            0.00                 0.00
# 2  b'Law'              19.00           18.00                19.00
# 3  b'Law'              30.00            5.00                15.00
# 4  b'Law'              30.00           10.00                20.00
# 5  b'Law'              50.00            0.00                30.00
# 6  b'Law'              35.00           15.00                25.00
# 7  b'Law'              33.33           11.11                11.11
# 8  b'Law'              50.00            0.00                25.00
# 9  b'Law'             100.00            0.00                 0.00
#
#    pref_o_funny  pref_o_ambitious  pref_o_shared_interests  \
# 0         20.00              0.00                     5.00
# 1         40.00              0.00                     0.00
# 2         18.00             14.00                    12.00
# 3         40.00              5.00                     5.00
# 4         10.00             10.00                    20.00
# 5         10.00              0.00                    10.00
# 6         10.00              5.00                    10.00
# 7         11.11             11.11                    22.22
# 8         10.00              0.00                    15.00
# 9          0.00              0.00                     0.00
#
#   d_pref_o_attractive d_pref_o_sincere d_pref_o_intelligence d_pref_o_funny  \
# 0         b'[21-100]'       b'[16-20]'            b'[16-20]'     b'[16-20]'
# 1         b'[21-100]'        b'[0-15]'             b'[0-15]'    b'[21-100]'
# 2          b'[16-20]'       b'[16-20]'            b'[16-20]'     b'[16-20]'
# 3         b'[21-100]'        b'[0-15]'             b'[0-15]'    b'[21-100]'
# 4         b'[21-100]'        b'[0-15]'            b'[16-20]'      b'[0-15]'
# 5         b'[21-100]'        b'[0-15]'           b'[21-100]'      b'[0-15]'
# 6         b'[21-100]'        b'[0-15]'           b'[21-100]'      b'[0-15]'
# 7         b'[21-100]'        b'[0-15]'             b'[0-15]'      b'[0-15]'
# 8         b'[21-100]'        b'[0-15]'           b'[21-100]'      b'[0-15]'
# 9         b'[21-100]'        b'[0-15]'             b'[0-15]'      b'[0-15]'
#
#   d_pref_o_ambitious d_pref_o_shared_interests  attractive_o  sinsere_o  \
# 0          b'[0-15]'                 b'[0-15]'           6.0        8.0
# 1          b'[0-15]'                 b'[0-15]'           7.0        8.0
# 2          b'[0-15]'                 b'[0-15]'          10.0       10.0
# 3          b'[0-15]'                 b'[0-15]'           7.0        8.0
# 4          b'[0-15]'                b'[16-20]'           8.0        7.0
# 5          b'[0-15]'                 b'[0-15]'           7.0        7.0
# 6          b'[0-15]'                 b'[0-15]'           3.0        6.0
# 7          b'[0-15]'               b'[21-100]'           6.0        7.0
# 8          b'[0-15]'                 b'[0-15]'           7.0        7.0
# 9          b'[0-15]'                 b'[0-15]'           6.0        6.0
#
#    intelligence_o  funny_o  ambitous_o  shared_interests_o d_attractive_o  \
# 0             8.0      8.0         8.0                 6.0       b'[6-8]'
# 1            10.0      7.0         7.0                 5.0       b'[6-8]'
# 2            10.0     10.0        10.0                10.0      b'[9-10]'
# 3             9.0      8.0         9.0                 8.0       b'[6-8]'
# 4             9.0      6.0         9.0                 7.0       b'[6-8]'
# 5             8.0      8.0         7.0                 7.0       b'[6-8]'
# 6             7.0      5.0         8.0                 7.0       b'[0-5]'
# 7             5.0      6.0         8.0                 6.0       b'[6-8]'
# 8             8.0      8.0         8.0                 9.0       b'[6-8]'
# 9             6.0      6.0         6.0                 6.0       b'[6-8]'
#
#   d_sinsere_o d_intelligence_o  d_funny_o d_ambitous_o d_shared_interests_o  \
# 0    b'[6-8]'         b'[6-8]'   b'[6-8]'     b'[6-8]'             b'[6-8]'
# 1    b'[6-8]'        b'[9-10]'   b'[6-8]'     b'[6-8]'             b'[0-5]'
# 2   b'[9-10]'        b'[9-10]'  b'[9-10]'    b'[9-10]'            b'[9-10]'
# 3    b'[6-8]'        b'[9-10]'   b'[6-8]'    b'[9-10]'             b'[6-8]'
# 4    b'[6-8]'        b'[9-10]'   b'[6-8]'    b'[9-10]'             b'[6-8]'
# 5    b'[6-8]'         b'[6-8]'   b'[6-8]'     b'[6-8]'             b'[6-8]'
# 6    b'[6-8]'         b'[6-8]'   b'[0-5]'     b'[6-8]'             b'[6-8]'
# 7    b'[6-8]'         b'[0-5]'   b'[6-8]'     b'[6-8]'             b'[6-8]'
# 8    b'[6-8]'         b'[6-8]'   b'[6-8]'     b'[6-8]'            b'[9-10]'
# 9    b'[6-8]'         b'[6-8]'   b'[6-8]'     b'[6-8]'             b'[6-8]'
#
#    attractive_important  sincere_important  intellicence_important  \
# 0                  15.0               20.0                    20.0
# 1                  15.0               20.0                    20.0
# 2                  15.0               20.0                    20.0
# 3                  15.0               20.0                    20.0
# 4                  15.0               20.0                    20.0
# 5                  15.0               20.0                    20.0
# 6                  15.0               20.0                    20.0
# 7                  15.0               20.0                    20.0
# 8                  15.0               20.0                    20.0
# 9                  15.0               20.0                    20.0
#
#    funny_important  ambtition_important  shared_interests_important  \
# 0             15.0                 15.0                        15.0
# 1             15.0                 15.0                        15.0
# 2             15.0                 15.0                        15.0
# 3             15.0                 15.0                        15.0
# 4             15.0                 15.0                        15.0
# 5             15.0                 15.0                        15.0
# 6             15.0                 15.0                        15.0
# 7             15.0                 15.0                        15.0
# 8             15.0                 15.0                        15.0
# 9             15.0                 15.0                        15.0
#
#   d_attractive_important d_sincere_important d_intellicence_important  \
# 0              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 1              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 2              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 3              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 4              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 5              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 6              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 7              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 8              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 9              b'[0-15]'          b'[16-20]'               b'[16-20]'
#
#   d_funny_important d_ambtition_important d_shared_interests_important  \
# 0         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 1         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 2         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 3         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 4         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 5         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 6         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 7         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 8         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 9         b'[0-15]'             b'[0-15]'                    b'[0-15]'
#
#    attractive  sincere  intelligence  funny  ambition d_attractive d_sincere  \
# 0         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 1         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 2         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 3         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 4         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 5         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 6         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 7         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 8         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 9         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
#
#   d_intelligence   d_funny d_ambition  attractive_partner  sincere_partner  \
# 0       b'[6-8]'  b'[6-8]'   b'[6-8]'                 6.0              9.0
# 1       b'[6-8]'  b'[6-8]'   b'[6-8]'                 7.0              8.0
# 2       b'[6-8]'  b'[6-8]'   b'[6-8]'                 5.0              8.0
# 3       b'[6-8]'  b'[6-8]'   b'[6-8]'                 7.0              6.0
# 4       b'[6-8]'  b'[6-8]'   b'[6-8]'                 5.0              6.0
# 5       b'[6-8]'  b'[6-8]'   b'[6-8]'                 4.0              9.0
# 6       b'[6-8]'  b'[6-8]'   b'[6-8]'                 7.0              6.0
# 7       b'[6-8]'  b'[6-8]'   b'[6-8]'                 4.0              9.0
# 8       b'[6-8]'  b'[6-8]'   b'[6-8]'                 7.0              6.0
# 9       b'[6-8]'  b'[6-8]'   b'[6-8]'                 5.0              6.0
#
#    intelligence_partner  funny_partner  ambition_partner  \
# 0                   7.0            7.0               6.0
# 1                   7.0            8.0               5.0
# 2                   9.0            8.0               5.0
# 3                   8.0            7.0               6.0
# 4                   7.0            7.0               6.0
# 5                   7.0            4.0               6.0
# 6                   7.0            4.0               6.0
# 7                   7.0            6.0               5.0
# 8                   8.0            9.0               8.0
# 9                   6.0            8.0              10.0
#
#    shared_interests_partner d_attractive_partner d_sincere_partner  \
# 0                       5.0             b'[6-8]'         b'[9-10]'
# 1                       6.0             b'[6-8]'          b'[6-8]'
# 2                       7.0             b'[0-5]'          b'[6-8]'
# 3                       8.0             b'[6-8]'          b'[6-8]'
# 4                       6.0             b'[0-5]'          b'[6-8]'
# 5                       4.0             b'[0-5]'         b'[9-10]'
# 6                       7.0             b'[6-8]'          b'[6-8]'
# 7                       6.0             b'[0-5]'         b'[9-10]'
# 8                       8.0             b'[6-8]'          b'[6-8]'
# 9                       8.0             b'[0-5]'          b'[6-8]'
#
#   d_intelligence_partner d_funny_partner d_ambition_partner  \
# 0               b'[6-8]'        b'[6-8]'           b'[6-8]'
# 1               b'[6-8]'        b'[6-8]'           b'[0-5]'
# 2              b'[9-10]'        b'[6-8]'           b'[0-5]'
# 3               b'[6-8]'        b'[6-8]'           b'[6-8]'
# 4               b'[6-8]'        b'[6-8]'           b'[6-8]'
# 5               b'[6-8]'        b'[0-5]'           b'[6-8]'
# 6               b'[6-8]'        b'[0-5]'           b'[6-8]'
# 7               b'[6-8]'        b'[6-8]'           b'[0-5]'
# 8               b'[6-8]'       b'[9-10]'           b'[6-8]'
# 9               b'[6-8]'        b'[6-8]'          b'[9-10]'
#
#   d_shared_interests_partner  sports  tvsports  exercise  dining  museums  \
# 0                   b'[0-5]'     9.0       2.0       8.0     9.0      1.0
# 1                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
# 2                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
# 3                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
# 4                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
# 5                   b'[0-5]'     9.0       2.0       8.0     9.0      1.0
# 6                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
# 7                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
# 8                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
# 9                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
#
#    art  hiking  gaming  clubbing  reading   tv  theater  movies  concerts  \
# 0  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 1  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 2  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 3  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 4  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 5  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 6  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 7  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 8  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 9  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
#
#    music  shopping  yoga   d_sports d_tvsports d_exercise   d_dining  \
# 0    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 1    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 2    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 3    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 4    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 5    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 6    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 7    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 8    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 9    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
#
#   d_museums     d_art  d_hiking  d_gaming d_clubbing d_reading       d_tv  \
# 0  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 1  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 2  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 3  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 4  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 5  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 6  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 7  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 8  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 9  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
#
#   d_theater   d_movies d_concerts    d_music d_shopping    d_yoga  \
# 0  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 1  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 2  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 3  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 4  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 5  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 6  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 7  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 8  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 9  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
#
#    interests_correlate d_interests_correlate  expected_happy_with_sd_people  \
# 0                 0.14           b'[0-0.33]'                            3.0
# 1                 0.54           b'[0.33-1]'                            3.0
# 2                 0.16           b'[0-0.33]'                            3.0
# 3                 0.61           b'[0.33-1]'                            3.0
# 4                 0.21           b'[0-0.33]'                            3.0
# 5                 0.25           b'[0-0.33]'                            3.0
# 6                 0.34           b'[0.33-1]'                            3.0
# 7                 0.50           b'[0.33-1]'                            3.0
# 8                 0.28           b'[0-0.33]'                            3.0
# 9                -0.36             b'[-1-0]'                            3.0
#
#    expected_num_interested_in_me  expected_num_matches  \
# 0                            2.0                   4.0
# 1                            2.0                   4.0
# 2                            2.0                   4.0
# 3                            2.0                   4.0
# 4                            2.0                   4.0
# 5                            2.0                   4.0
# 6                            2.0                   4.0
# 7                            2.0                   4.0
# 8                            2.0                   4.0
# 9                            2.0                   4.0
#
#   d_expected_happy_with_sd_people d_expected_num_interested_in_me  \
# 0                        b'[0-4]'                        b'[0-3]'
# 1                        b'[0-4]'                        b'[0-3]'
# 2                        b'[0-4]'                        b'[0-3]'
# 3                        b'[0-4]'                        b'[0-3]'
# 4                        b'[0-4]'                        b'[0-3]'
# 5                        b'[0-4]'                        b'[0-3]'
# 6                        b'[0-4]'                        b'[0-3]'
# 7                        b'[0-4]'                        b'[0-3]'
# 8                        b'[0-4]'                        b'[0-3]'
# 9                        b'[0-4]'                        b'[0-3]'
#
#   d_expected_num_matches  like  guess_prob_liked    d_like d_guess_prob_liked  \
# 0               b'[3-5]'   7.0               6.0  b'[6-8]'           b'[5-6]'
# 1               b'[3-5]'   7.0               5.0  b'[6-8]'           b'[5-6]'
# 2               b'[3-5]'   7.0               NaN  b'[6-8]'           b'[0-4]'
# 3               b'[3-5]'   7.0               6.0  b'[6-8]'           b'[5-6]'
# 4               b'[3-5]'   6.0               6.0  b'[6-8]'           b'[5-6]'
# 5               b'[3-5]'   6.0               5.0  b'[6-8]'           b'[5-6]'
# 6               b'[3-5]'   6.0               5.0  b'[6-8]'           b'[5-6]'
# 7               b'[3-5]'   6.0               7.0  b'[6-8]'          b'[7-10]'
# 8               b'[3-5]'   7.0               7.0  b'[6-8]'          b'[7-10]'
# 9               b'[3-5]'   6.0               6.0  b'[6-8]'           b'[5-6]'
#
#    met decision decision_o match
# 0  0.0     b'1'       b'0'  b'0'
# 1  1.0     b'1'       b'0'  b'0'
# 2  1.0     b'1'       b'1'  b'1'
# 3  0.0     b'1'       b'1'  b'1'
# 4  0.0     b'1'       b'1'  b'1'
# 5  0.0     b'0'       b'1'  b'0'
# 6  0.0     b'1'       b'0'  b'0'
# 7  NaN     b'0'       b'0'  b'0'
# 8  0.0     b'1'       b'1'  b'1'
# 9  0.0     b'1'       b'0'  b'0'

# %% [markdown]
# ### 3. Exploratory Data Analysis
# we going to perform EDA both categorical and numerical columns of data set

# %% [markdown]
# #### 3.1 First glimpse of data

# %% [markdown]
# We will take a look at our dataframe and the output below shows that
# the dating data contain both categorical and numerical. (Which shown in Float and object)

# %%
## Looking at data type of data set
dating.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8378 entries, 0 to 8377
# Data columns (total 123 columns):
#  #    Column                           Non-Null Count  Dtype
# ---   ------                           --------------  -----
#  0    has_null                         8378 non-null   object
#  1    wave                             8378 non-null   float64
#  2    gender                           8378 non-null   object
#  3    age                              8283 non-null   float64
#  4    age_o                            8274 non-null   float64
#  5    d_age                            8378 non-null   float64
#  6    d_d_age                          8378 non-null   object
#  7    race                             8378 non-null   object
#  8    race_o                           8378 non-null   object
#  9    samerace                         8378 non-null   object
#  10   importance_same_race             8299 non-null   float64
#  11   importance_same_religion         8299 non-null   float64
#  12   d_importance_same_race           8378 non-null   object
#  13   d_importance_same_religion       8378 non-null   object
#  14   field                            8378 non-null   object
#  15   pref_o_attractive                8289 non-null   float64
#  16   pref_o_sincere                   8289 non-null   float64
#  17   pref_o_intelligence              8289 non-null   float64
#  18   pref_o_funny                     8280 non-null   float64
#  19   pref_o_ambitious                 8271 non-null   float64
#  20   pref_o_shared_interests          8249 non-null   float64
#  21   d_pref_o_attractive              8378 non-null   object
#  22   d_pref_o_sincere                 8378 non-null   object
#  23   d_pref_o_intelligence            8378 non-null   object
#  24   d_pref_o_funny                   8378 non-null   object
#  25   d_pref_o_ambitious               8378 non-null   object
#  26   d_pref_o_shared_interests        8378 non-null   object
#  27   attractive_o                     8166 non-null   float64
#  28   sinsere_o                        8091 non-null   float64
#  29   intelligence_o                   8072 non-null   float64
#  30   funny_o                          8018 non-null   float64
#  31   ambitous_o                       7656 non-null   float64
#  32   shared_interests_o               7302 non-null   float64
#  33   d_attractive_o                   8378 non-null   object
#  34   d_sinsere_o                      8378 non-null   object
#  35   d_intelligence_o                 8378 non-null   object
#  36   d_funny_o                        8378 non-null   object
#  37   d_ambitous_o                     8378 non-null   object
#  38   d_shared_interests_o             8378 non-null   object
#  39   attractive_important             8299 non-null   float64
#  40   sincere_important                8299 non-null   float64
#  41   intellicence_important           8299 non-null   float64
#  42   funny_important                  8289 non-null   float64
#  43   ambtition_important              8279 non-null   float64
#  44   shared_interests_important       8257 non-null   float64
#  45   d_attractive_important           8378 non-null   object
#  46   d_sincere_important              8378 non-null   object
#  47   d_intellicence_important         8378 non-null   object
#  48   d_funny_important                8378 non-null   object
#  49   d_ambtition_important            8378 non-null   object
#  50   d_shared_interests_important     8378 non-null   object
#  51   attractive                       8273 non-null   float64
#  52   sincere                          8273 non-null   float64
#  53   intelligence                     8273 non-null   float64
#  54   funny                            8273 non-null   float64
#  55   ambition                         8273 non-null   float64
#  56   d_attractive                     8378 non-null   object
#  57   d_sincere                        8378 non-null   object
#  58   d_intelligence                   8378 non-null   object
#  59   d_funny                          8378 non-null   object
#  60   d_ambition                       8378 non-null   object
#  61   attractive_partner               8176 non-null   float64
#  62   sincere_partner                  8101 non-null   float64
#  63   intelligence_partner             8082 non-null   float64
#  64   funny_partner                    8028 non-null   float64
#  65   ambition_partner                 7666 non-null   float64
#  66   shared_interests_partner         7311 non-null   float64
#  67   d_attractive_partner             8378 non-null   object
#  68   d_sincere_partner                8378 non-null   object
#  69   d_intelligence_partner           8378 non-null   object
#  70   d_funny_partner                  8378 non-null   object
#  71   d_ambition_partner               8378 non-null   object
#  72   d_shared_interests_partner       8378 non-null   object
#  73   sports                           8299 non-null   float64
#  74   tvsports                         8299 non-null   float64
#  75   exercise                         8299 non-null   float64
#  76   dining                           8299 non-null   float64
#  77   museums                          8299 non-null   float64
#  78   art                              8299 non-null   float64
#  79   hiking                           8299 non-null   float64
#  80   gaming                           8299 non-null   float64
#  81   clubbing                         8299 non-null   float64
#  82   reading                          8299 non-null   float64
#  83   tv                               8299 non-null   float64
#  84   theater                          8299 non-null   float64
#  85   movies                           8299 non-null   float64
#  86   concerts                         8299 non-null   float64
#  87   music                            8299 non-null   float64
#  88   shopping                         8299 non-null   float64
#  89   yoga                             8299 non-null   float64
#  90   d_sports                         8378 non-null   object
#  91   d_tvsports                       8378 non-null   object
#  92   d_exercise                       8378 non-null   object
#  93   d_dining                         8378 non-null   object
#  94   d_museums                        8378 non-null   object
#  95   d_art                            8378 non-null   object
#  96   d_hiking                         8378 non-null   object
#  97   d_gaming                         8378 non-null   object
#  98   d_clubbing                       8378 non-null   object
#  99   d_reading                        8378 non-null   object
#  100  d_tv                             8378 non-null   object
#  101  d_theater                        8378 non-null   object
#  102  d_movies                         8378 non-null   object
#  103  d_concerts                       8378 non-null   object
#  104  d_music                          8378 non-null   object
#  105  d_shopping                       8378 non-null   object
#  106  d_yoga                           8378 non-null   object
#  107  interests_correlate              8220 non-null   float64
#  108  d_interests_correlate            8378 non-null   object
#  109  expected_happy_with_sd_people    8277 non-null   float64
#  110  expected_num_interested_in_me    1800 non-null   float64
#  111  expected_num_matches             7205 non-null   float64
#  112  d_expected_happy_with_sd_people  8378 non-null   object
#  113  d_expected_num_interested_in_me  8378 non-null   object
#  114  d_expected_num_matches           8378 non-null   object
#  115  like                             8138 non-null   float64
#  116  guess_prob_liked                 8069 non-null   float64
#  117  d_like                           8378 non-null   object
#  118  d_guess_prob_liked               8378 non-null   object
#  119  met                              8003 non-null   float64
#  120  decision                         8378 non-null   object
#  121  decision_o                       8378 non-null   object
#  122  match                            8378 non-null   object
# dtypes: float64(59), object(64)
# memory usage: 7.9+ MB

# %% [markdown]
# as we can see from the output it shows that this dataset contain missing value. Since the number of value in some column is not equal to 8738

# %%
dating.dtypes.value_counts()
# Out:
# object     64
# float64    59
# dtype: int64

# %% [markdown]
# The speed dating dataset consist of
# 64 column of data are object(string)
# 59 column of data are float
# 123 column total

# %%
pd.set_option('display.max_rows', None)
dating.nunique().sort_values()
# Out:
# has_null                             1
# decision                             2
# decision_o                           2
# samerace                             2
# match                                2
# gender                               2
# d_gaming                             3
# d_funny_o                            3
# d_ambitous_o                         3
# d_shared_interests_o                 3
# d_music                              3
# d_concerts                           3
# d_movies                             3
# d_theater                            3
# d_tv                                 3
# d_reading                            3
# d_attractive_important               3
# d_sincere_important                  3
# d_intellicence_important             3
# d_funny_important                    3
# d_ambtition_important                3
# d_shared_interests_important         3
# d_hiking                             3
# d_ambition_partner                   3
# d_funny_partner                      3
# d_intelligence_partner               3
# d_attractive                         3
# d_sincere                            3
# d_intelligence                       3
# d_funny                              3
# d_ambition                           3
# d_sincere_partner                    3
# d_intelligence_o                     3
# d_clubbing                           3
# d_sinsere_o                          3
# d_shared_interests_partner           3
# d_art                                3
# d_museums                            3
# d_importance_same_race               3
# d_importance_same_religion           3
# d_guess_prob_liked                   3
# d_like                               3
# d_expected_num_matches               3
# d_expected_num_interested_in_me      3
# d_attractive_o                       3
# d_dining                             3
# d_exercise                           3
# d_expected_happy_with_sd_people      3
# d_pref_o_sincere                     3
# d_sports                             3
# d_shopping                           3
# d_pref_o_attractive                  3
# d_tvsports                           3
# d_yoga                               3
# d_pref_o_shared_interests            3
# d_pref_o_ambitious                   3
# d_pref_o_funny                       3
# d_pref_o_intelligence                3
# d_interests_correlate                3
# d_attractive_partner                 3
# d_d_age                              4
# race_o                               6
# race                                 6
# met                                  7
# funny                                8
# attractive                           9
# ambition                             9
# intelligence                         9
# sincere                              9
# shopping                            10
# music                               10
# importance_same_religion            10
# sports                              10
# tvsports                            10
# exercise                            10
# dining                              10
# movies                              10
# tv                                  10
# expected_happy_with_sd_people       10
# clubbing                            11
# concerts                            11
# theater                             11
# art                                 11
# hiking                              11
# yoga                                11
# museums                             11
# importance_same_race                11
# reading                             11
# gaming                              12
# sincere_partner                     14
# sinsere_o                           14
# shared_interests_partner            15
# ambition_partner                    15
# shared_interests_o                  15
# ambitous_o                          15
# funny_partner                       16
# expected_num_matches                17
# intelligence_partner                17
# attractive_partner                  17
# funny_o                             17
# intelligence_o                      17
# expected_num_interested_in_me       18
# like                                18
# attractive_o                        18
# guess_prob_liked                    19
# wave                                21
# age                                 24
# age_o                               24
# d_age                               35
# pref_o_intelligence                 65
# intellicence_important              65
# pref_o_funny                        71
# funny_important                     71
# pref_o_sincere                      78
# sincere_important                   78
# pref_o_ambitious                    82
# ambtition_important                 82
# pref_o_shared_interests             85
# shared_interests_important          85
# attractive_important                94
# pref_o_attractive                   94
# interests_correlate                155
# field                              260
# dtype: int64

# %% [markdown]
# the output shows the unique value of each columns which point out that the column "field" contain various value of answer which we will continue to explore about it later

# %%
dating.describe()
# Out:
#               wave          age        age_o        d_age  \
# count  8378.000000  8283.000000  8274.000000  8378.000000
# mean     11.350919    26.358928    26.364999     4.185605
# std       5.995903     3.566763     3.563648     4.596171
# min       1.000000    18.000000    18.000000     0.000000
# 25%       7.000000    24.000000    24.000000     1.000000
# 50%      11.000000    26.000000    26.000000     3.000000
# 75%      15.000000    28.000000    28.000000     5.000000
# max      21.000000    55.000000    55.000000    37.000000
#
#        importance_same_race  importance_same_religion  pref_o_attractive  \
# count           8299.000000               8299.000000        8289.000000
# mean               3.784793                  3.651645          22.495347
# std                2.845708                  2.805237          12.569802
# min                0.000000                  1.000000           0.000000
# 25%                1.000000                  1.000000          15.000000
# 50%                3.000000                  3.000000          20.000000
# 75%                6.000000                  6.000000          25.000000
# max               10.000000                 10.000000         100.000000
#
#        pref_o_sincere  pref_o_intelligence  pref_o_funny  pref_o_ambitious  \
# count     8289.000000          8289.000000   8280.000000       8271.000000
# mean        17.396867            20.270759     17.459714         10.685375
# std          7.044003             6.782895      6.085526          6.126544
# min          0.000000             0.000000      0.000000          0.000000
# 25%         15.000000            17.390000     15.000000          5.000000
# 50%         18.370000            20.000000     18.000000         10.000000
# 75%         20.000000            23.810000     20.000000         15.000000
# max         60.000000            50.000000     50.000000         53.000000
#
#        pref_o_shared_interests  attractive_o    sinsere_o  intelligence_o  \
# count              8249.000000   8166.000000  8091.000000     8072.000000
# mean                 11.845930      6.190411     7.175256        7.369301
# std                   6.362746      1.950305     1.740575        1.550501
# min                   0.000000      0.000000     0.000000        0.000000
# 25%                   9.520000      5.000000     6.000000        6.000000
# 50%                  10.640000      6.000000     7.000000        7.000000
# 75%                  16.000000      8.000000     8.000000        8.000000
# max                  30.000000     10.500000    10.000000       10.000000
#
#            funny_o   ambitous_o  shared_interests_o  attractive_important  \
# count  8018.000000  7656.000000         7302.000000           8299.000000
# mean      6.400599     6.778409            5.474870             22.514632
# std       1.954078     1.794080            2.156163             12.587674
# min       0.000000     0.000000            0.000000              0.000000
# 25%       5.000000     6.000000            4.000000             15.000000
# 50%       7.000000     7.000000            6.000000             20.000000
# 75%       8.000000     8.000000            7.000000             25.000000
# max      11.000000    10.000000           10.000000            100.000000
#
#        sincere_important  intellicence_important  funny_important  \
# count        8299.000000             8299.000000      8289.000000
# mean           17.396389               20.265613        17.457043
# std             7.046700                6.783003         6.085239
# min             0.000000                0.000000         0.000000
# 25%            15.000000               17.390000        15.000000
# 50%            18.180000               20.000000        18.000000
# 75%            20.000000               23.810000        20.000000
# max            60.000000               50.000000        50.000000
#
#        ambtition_important  shared_interests_important   attractive  \
# count          8279.000000                 8257.000000  8273.000000
# mean             10.682539                   11.845111     7.084733
# std               6.124888                    6.362154     1.395783
# min               0.000000                    0.000000     2.000000
# 25%               5.000000                    9.520000     6.000000
# 50%              10.000000                   10.640000     7.000000
# 75%              15.000000                   16.000000     8.000000
# max              53.000000                   30.000000    10.000000
#
#            sincere  intelligence        funny     ambition  \
# count  8273.000000   8273.000000  8273.000000  8273.000000
# mean      8.294935      7.704460     8.403965     7.578388
# std       1.407460      1.564321     1.076608     1.778315
# min       2.000000      2.000000     3.000000     2.000000
# 25%       8.000000      7.000000     8.000000     7.000000
# 50%       8.000000      8.000000     8.000000     8.000000
# 75%       9.000000      9.000000     9.000000     9.000000
# max      10.000000     10.000000    10.000000    10.000000
#
#        attractive_partner  sincere_partner  intelligence_partner  \
# count         8176.000000      8101.000000           8082.000000
# mean             6.189995         7.175164              7.368597
# std              1.950169         1.740315              1.550453
# min              0.000000         0.000000              0.000000
# 25%              5.000000         6.000000              6.000000
# 50%              6.000000         7.000000              7.000000
# 75%              8.000000         8.000000              8.000000
# max             10.000000        10.000000             10.000000
#
#        funny_partner  ambition_partner  shared_interests_partner       sports  \
# count    8028.000000       7666.000000               7311.000000  8299.000000
# mean        6.400598          6.777524                  5.474559     6.425232
# std         1.953702          1.794055                  2.156363     2.619024
# min         0.000000          0.000000                  0.000000     1.000000
# 25%         5.000000          6.000000                  4.000000     4.000000
# 50%         7.000000          7.000000                  6.000000     7.000000
# 75%         8.000000          8.000000                  7.000000     9.000000
# max        10.000000         10.000000                 10.000000    10.000000
#
#           tvsports     exercise       dining      museums          art  \
# count  8299.000000  8299.000000  8299.000000  8299.000000  8299.000000
# mean      4.575491     6.245813     7.783829     6.985781     6.714544
# std       2.801874     2.418858     1.754868     2.052232     2.263407
# min       1.000000     1.000000     1.000000     0.000000     0.000000
# 25%       2.000000     5.000000     7.000000     6.000000     5.000000
# 50%       4.000000     6.000000     8.000000     7.000000     7.000000
# 75%       7.000000     8.000000     9.000000     9.000000     8.000000
# max      10.000000    10.000000    10.000000    10.000000    10.000000
#
#             hiking       gaming     clubbing      reading           tv  \
# count  8299.000000  8299.000000  8299.000000  8299.000000  8299.000000
# mean      5.737077     3.881191     5.745993     7.678515     5.304133
# std       2.570207     2.620507     2.502218     2.006565     2.529135
# min       0.000000     0.000000     0.000000     1.000000     1.000000
# 25%       4.000000     2.000000     4.000000     7.000000     3.000000
# 50%       6.000000     3.000000     6.000000     8.000000     6.000000
# 75%       8.000000     6.000000     8.000000     9.000000     7.000000
# max      10.000000    14.000000    10.000000    13.000000    10.000000
#
#            theater       movies     concerts        music     shopping  \
# count  8299.000000  8299.000000  8299.000000  8299.000000  8299.000000
# mean      6.776118     7.919629     6.825401     7.851066     5.631281
# std       2.235152     1.700927     2.156283     1.791827     2.608913
# min       0.000000     0.000000     0.000000     1.000000     1.000000
# 25%       5.000000     7.000000     5.000000     7.000000     4.000000
# 50%       7.000000     8.000000     7.000000     8.000000     6.000000
# 75%       9.000000     9.000000     8.000000     9.000000     8.000000
# max      10.000000    10.000000    10.000000    10.000000    10.000000
#
#               yoga  interests_correlate  expected_happy_with_sd_people  \
# count  8299.000000          8220.000000                    8277.000000
# mean      4.339197             0.196010                       5.534131
# std       2.717612             0.303539                       1.734059
# min       0.000000            -0.830000                       1.000000
# 25%       2.000000            -0.020000                       5.000000
# 50%       4.000000             0.210000                       6.000000
# 75%       7.000000             0.430000                       7.000000
# max      10.000000             0.910000                      10.000000
#
#        expected_num_interested_in_me  expected_num_matches         like  \
# count                    1800.000000           7205.000000  8138.000000
# mean                        5.570556              3.207814     6.134087
# std                         4.762569              2.444813     1.841285
# min                         0.000000              0.000000     0.000000
# 25%                         2.000000              2.000000     5.000000
# 50%                         4.000000              3.000000     6.000000
# 75%                         8.000000              4.000000     7.000000
# max                        20.000000             18.000000    10.000000
#
#        guess_prob_liked          met
# count       8069.000000  8003.000000
# mean           5.207523     0.049856
# std            2.129565     0.282168
# min            0.000000     0.000000
# 25%            4.000000     0.000000
# 50%            5.000000     0.000000
# 75%            7.000000     0.000000
# max           10.000000     8.000000

# %% [markdown]
# #### 3.2 Missing value

# %% [markdown]
# We will find the missing value that each column contain and consider to remove it with our criteria

# %%
# find missing values
missing_values = dating.isnull().sum()

# print the number of missing values in each column
print('Missing values in the dataset:\n')
counter = 0
for column_name, count in missing_values.items():
    if count > 0:
        print('Column: {} - {}'.format(column_name, count))
        counter += 1

print('the total missing value column  : {} columns'.format(counter))
# Out:
# Missing values in the dataset:
#
# Column: age - 95
# Column: age_o - 104
# Column: importance_same_race - 79
# Column: importance_same_religion - 79
# Column: pref_o_attractive - 89
# Column: pref_o_sincere - 89
# Column: pref_o_intelligence - 89
# Column: pref_o_funny - 98
# Column: pref_o_ambitious - 107
# Column: pref_o_shared_interests - 129
# Column: attractive_o - 212
# Column: sinsere_o - 287
# Column: intelligence_o - 306
# Column: funny_o - 360
# Column: ambitous_o - 722
# Column: shared_interests_o - 1076
# Column: attractive_important - 79
# Column: sincere_important - 79
# Column: intellicence_important - 79
# Column: funny_important - 89
# Column: ambtition_important - 99
# Column: shared_interests_important - 121
# Column: attractive - 105
# Column: sincere - 105
# Column: intelligence - 105
# Column: funny - 105
# Column: ambition - 105
# Column: attractive_partner - 202
# Column: sincere_partner - 277
# Column: intelligence_partner - 296
# Column: funny_partner - 350
# Column: ambition_partner - 712
# Column: shared_interests_partner - 1067
# Column: sports - 79
# Column: tvsports - 79
# Column: exercise - 79
# Column: dining - 79
# Column: museums - 79
# Column: art - 79
# Column: hiking - 79
# Column: gaming - 79
# Column: clubbing - 79
# Column: reading - 79
# Column: tv - 79
# Column: theater - 79
# Column: movies - 79
# Column: concerts - 79
# Column: music - 79
# Column: shopping - 79
# Column: yoga - 79
# Column: interests_correlate - 158
# Column: expected_happy_with_sd_people - 101
# Column: expected_num_interested_in_me - 6578
# Column: expected_num_matches - 1173
# Column: like - 240
# Column: guess_prob_liked - 309
# Column: met - 375
# the total missing value column  : 57 columns

# %% [markdown]
# ##### There are  57 column that contain missing value in dataset

# %%
### Visual representation of the missing data in the dataset

missingno.matrix(dating)

# sort missing value then drop row
# Out:
# <AxesSubplot: >

# %% [markdown]
# #### 3.3 Age distribution

# %% [markdown]
# Majority number of age of participants lies between 22-27

# %%
# Extract the "Age" column from the DataFrame
ages = dating['age']

# Create a histogram of the "Age" column
plt.hist(ages, bins=20, color='aquamarine', edgecolor='black')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.title('Age Distribution')
plt.show()


# Extract the "Age_o" column from the DataFrame
agespartner = dating['age_o']

# Create a histogram of the "Age" column
plt.hist(agespartner, bins=20, color='mediumpurple', edgecolor='black')
plt.xlabel('Partner Age')
plt.ylabel('Frequency')
plt.title('Partner Age Distribution')
plt.show()

# %% [markdown]
# Boxplot age

# %%
dating[['age', 'age_o']].boxplot()
# Out:
# <AxesSubplot: >

# %% [markdown]
# The box-plot may identify age at 55 as an outlier but according to the nature of data at this age number is still a reasonable number so we consider to keep it.

# %% [markdown]
# #### 3.4 Distribution of target (column : "match" (0,1))

# %%
target = dating['match'] 
print("Unique values in 'match' column:", target.unique())
# Out:
# Unique values in 'match' column: ["b'0'" "b'1'"]

# %%
print("Target variable distribution:")
print(target.value_counts(normalize=True))
# Out:
# Target variable distribution:
# b'0'    0.835283
# b'1'    0.164717
# Name: match, dtype: float64

# %% [markdown]
# According to the output above the proportion signal some imbalance in the target column

# %%
# Plot the distribution of the target variable
match_value_counts = dating['match'].value_counts()

# Create a bar chart
plt.bar(match_value_counts.index, match_value_counts.values, color=['skyblue','pink'])

# Add labels to each bar with count
for xbar, ybar in zip(match_value_counts.index, match_value_counts.values):
    plt.text(xbar, ybar, str(ybar), ha='center', va='bottom')

# Set the title and labels for the chart
plt.title('Count of Values in Match Column')
plt.xlabel('Unique Values')
plt.ylabel('Counts')

# Display the chart
plt.show()

# %% [markdown]
# The barplot shows that there is imbalance in target column "match"
# the data of not match : 0 is around triple amount of the value of match : 1

# %% [markdown]
# ### 4. Data Preprocessing

# %% [markdown]
# #### 4.1 Checking column data types

# %%
dating.dtypes
# Out:
# has_null                            object
# wave                               float64
# gender                              object
# age                                float64
# age_o                              float64
# d_age                              float64
# d_d_age                             object
# race                                object
# race_o                              object
# samerace                            object
# importance_same_race               float64
# importance_same_religion           float64
# d_importance_same_race              object
# d_importance_same_religion          object
# field                               object
# pref_o_attractive                  float64
# pref_o_sincere                     float64
# pref_o_intelligence                float64
# pref_o_funny                       float64
# pref_o_ambitious                   float64
# pref_o_shared_interests            float64
# d_pref_o_attractive                 object
# d_pref_o_sincere                    object
# d_pref_o_intelligence               object
# d_pref_o_funny                      object
# d_pref_o_ambitious                  object
# d_pref_o_shared_interests           object
# attractive_o                       float64
# sinsere_o                          float64
# intelligence_o                     float64
# funny_o                            float64
# ambitous_o                         float64
# shared_interests_o                 float64
# d_attractive_o                      object
# d_sinsere_o                         object
# d_intelligence_o                    object
# d_funny_o                           object
# d_ambitous_o                        object
# d_shared_interests_o                object
# attractive_important               float64
# sincere_important                  float64
# intellicence_important             float64
# funny_important                    float64
# ambtition_important                float64
# shared_interests_important         float64
# d_attractive_important              object
# d_sincere_important                 object
# d_intellicence_important            object
# d_funny_important                   object
# d_ambtition_important               object
# d_shared_interests_important        object
# attractive                         float64
# sincere                            float64
# intelligence                       float64
# funny                              float64
# ambition                           float64
# d_attractive                        object
# d_sincere                           object
# d_intelligence                      object
# d_funny                             object
# d_ambition                          object
# attractive_partner                 float64
# sincere_partner                    float64
# intelligence_partner               float64
# funny_partner                      float64
# ambition_partner                   float64
# shared_interests_partner           float64
# d_attractive_partner                object
# d_sincere_partner                   object
# d_intelligence_partner              object
# d_funny_partner                     object
# d_ambition_partner                  object
# d_shared_interests_partner          object
# sports                             float64
# tvsports                           float64
# exercise                           float64
# dining                             float64
# museums                            float64
# art                                float64
# hiking                             float64
# gaming                             float64
# clubbing                           float64
# reading                            float64
# tv                                 float64
# theater                            float64
# movies                             float64
# concerts                           float64
# music                              float64
# shopping                           float64
# yoga                               float64
# d_sports                            object
# d_tvsports                          object
# d_exercise                          object
# d_dining                            object
# d_museums                           object
# d_art                               object
# d_hiking                            object
# d_gaming                            object
# d_clubbing                          object
# d_reading                           object
# d_tv                                object
# d_theater                           object
# d_movies                            object
# d_concerts                          object
# d_music                             object
# d_shopping                          object
# d_yoga                              object
# interests_correlate                float64
# d_interests_correlate               object
# expected_happy_with_sd_people      float64
# expected_num_interested_in_me      float64
# expected_num_matches               float64
# d_expected_happy_with_sd_people     object
# d_expected_num_interested_in_me     object
# d_expected_num_matches              object
# like                               float64
# guess_prob_liked                   float64
# d_like                              object
# d_guess_prob_liked                  object
# met                                float64
# decision                            object
# decision_o                          object
# match                               object
# dtype: object

# %% [markdown]
# #### 4.2 Removing unwanted characters
# All string columns have an unwanted character 'b' and are enclosed by single quotes. We will remove these characters from the columns.

# %%
dating.head(3)
# Out:
#   has_null  wave     gender   age  age_o  d_age   d_d_age  \
# 0      b''   1.0  b'female'  21.0   27.0    6.0  b'[4-6]'
# 1      b''   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
# 2      b''   1.0  b'female'  21.0   22.0    1.0  b'[0-1]'
#
#                                        race  \
# 0  b'Asian/Pacific Islander/Asian-American'
# 1  b'Asian/Pacific Islander/Asian-American'
# 2  b'Asian/Pacific Islander/Asian-American'
#
#                                      race_o samerace  importance_same_race  \
# 0            b'European/Caucasian-American'     b'0'                   2.0
# 1            b'European/Caucasian-American'     b'0'                   2.0
# 2  b'Asian/Pacific Islander/Asian-American'     b'1'                   2.0
#
#    importance_same_religion d_importance_same_race d_importance_same_religion  \
# 0                       4.0               b'[2-5]'                   b'[2-5]'
# 1                       4.0               b'[2-5]'                   b'[2-5]'
# 2                       4.0               b'[2-5]'                   b'[2-5]'
#
#     field  pref_o_attractive  pref_o_sincere  pref_o_intelligence  \
# 0  b'Law'               35.0            20.0                 20.0
# 1  b'Law'               60.0             0.0                  0.0
# 2  b'Law'               19.0            18.0                 19.0
#
#    pref_o_funny  pref_o_ambitious  pref_o_shared_interests  \
# 0          20.0               0.0                      5.0
# 1          40.0               0.0                      0.0
# 2          18.0              14.0                     12.0
#
#   d_pref_o_attractive d_pref_o_sincere d_pref_o_intelligence d_pref_o_funny  \
# 0         b'[21-100]'       b'[16-20]'            b'[16-20]'     b'[16-20]'
# 1         b'[21-100]'        b'[0-15]'             b'[0-15]'    b'[21-100]'
# 2          b'[16-20]'       b'[16-20]'            b'[16-20]'     b'[16-20]'
#
#   d_pref_o_ambitious d_pref_o_shared_interests  attractive_o  sinsere_o  \
# 0          b'[0-15]'                 b'[0-15]'           6.0        8.0
# 1          b'[0-15]'                 b'[0-15]'           7.0        8.0
# 2          b'[0-15]'                 b'[0-15]'          10.0       10.0
#
#    intelligence_o  funny_o  ambitous_o  shared_interests_o d_attractive_o  \
# 0             8.0      8.0         8.0                 6.0       b'[6-8]'
# 1            10.0      7.0         7.0                 5.0       b'[6-8]'
# 2            10.0     10.0        10.0                10.0      b'[9-10]'
#
#   d_sinsere_o d_intelligence_o  d_funny_o d_ambitous_o d_shared_interests_o  \
# 0    b'[6-8]'         b'[6-8]'   b'[6-8]'     b'[6-8]'             b'[6-8]'
# 1    b'[6-8]'        b'[9-10]'   b'[6-8]'     b'[6-8]'             b'[0-5]'
# 2   b'[9-10]'        b'[9-10]'  b'[9-10]'    b'[9-10]'            b'[9-10]'
#
#    attractive_important  sincere_important  intellicence_important  \
# 0                  15.0               20.0                    20.0
# 1                  15.0               20.0                    20.0
# 2                  15.0               20.0                    20.0
#
#    funny_important  ambtition_important  shared_interests_important  \
# 0             15.0                 15.0                        15.0
# 1             15.0                 15.0                        15.0
# 2             15.0                 15.0                        15.0
#
#   d_attractive_important d_sincere_important d_intellicence_important  \
# 0              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 1              b'[0-15]'          b'[16-20]'               b'[16-20]'
# 2              b'[0-15]'          b'[16-20]'               b'[16-20]'
#
#   d_funny_important d_ambtition_important d_shared_interests_important  \
# 0         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 1         b'[0-15]'             b'[0-15]'                    b'[0-15]'
# 2         b'[0-15]'             b'[0-15]'                    b'[0-15]'
#
#    attractive  sincere  intelligence  funny  ambition d_attractive d_sincere  \
# 0         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 1         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
# 2         6.0      8.0           8.0    8.0       7.0     b'[6-8]'  b'[6-8]'
#
#   d_intelligence   d_funny d_ambition  attractive_partner  sincere_partner  \
# 0       b'[6-8]'  b'[6-8]'   b'[6-8]'                 6.0              9.0
# 1       b'[6-8]'  b'[6-8]'   b'[6-8]'                 7.0              8.0
# 2       b'[6-8]'  b'[6-8]'   b'[6-8]'                 5.0              8.0
#
#    intelligence_partner  funny_partner  ambition_partner  \
# 0                   7.0            7.0               6.0
# 1                   7.0            8.0               5.0
# 2                   9.0            8.0               5.0
#
#    shared_interests_partner d_attractive_partner d_sincere_partner  \
# 0                       5.0             b'[6-8]'         b'[9-10]'
# 1                       6.0             b'[6-8]'          b'[6-8]'
# 2                       7.0             b'[0-5]'          b'[6-8]'
#
#   d_intelligence_partner d_funny_partner d_ambition_partner  \
# 0               b'[6-8]'        b'[6-8]'           b'[6-8]'
# 1               b'[6-8]'        b'[6-8]'           b'[0-5]'
# 2              b'[9-10]'        b'[6-8]'           b'[0-5]'
#
#   d_shared_interests_partner  sports  tvsports  exercise  dining  museums  \
# 0                   b'[0-5]'     9.0       2.0       8.0     9.0      1.0
# 1                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
# 2                   b'[6-8]'     9.0       2.0       8.0     9.0      1.0
#
#    art  hiking  gaming  clubbing  reading   tv  theater  movies  concerts  \
# 0  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 1  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
# 2  1.0     5.0     1.0       5.0      6.0  9.0      1.0    10.0      10.0
#
#    music  shopping  yoga   d_sports d_tvsports d_exercise   d_dining  \
# 0    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 1    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
# 2    9.0       8.0   1.0  b'[9-10]'   b'[0-5]'   b'[6-8]'  b'[9-10]'
#
#   d_museums     d_art  d_hiking  d_gaming d_clubbing d_reading       d_tv  \
# 0  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 1  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
# 2  b'[0-5]'  b'[0-5]'  b'[0-5]'  b'[0-5]'   b'[0-5]'  b'[6-8]'  b'[9-10]'
#
#   d_theater   d_movies d_concerts    d_music d_shopping    d_yoga  \
# 0  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 1  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
# 2  b'[0-5]'  b'[9-10]'  b'[9-10]'  b'[9-10]'   b'[6-8]'  b'[0-5]'
#
#    interests_correlate d_interests_correlate  expected_happy_with_sd_people  \
# 0                 0.14           b'[0-0.33]'                            3.0
# 1                 0.54           b'[0.33-1]'                            3.0
# 2                 0.16           b'[0-0.33]'                            3.0
#
#    expected_num_interested_in_me  expected_num_matches  \
# 0                            2.0                   4.0
# 1                            2.0                   4.0
# 2                            2.0                   4.0
#
#   d_expected_happy_with_sd_people d_expected_num_interested_in_me  \
# 0                        b'[0-4]'                        b'[0-3]'
# 1                        b'[0-4]'                        b'[0-3]'
# 2                        b'[0-4]'                        b'[0-3]'
#
#   d_expected_num_matches  like  guess_prob_liked    d_like d_guess_prob_liked  \
# 0               b'[3-5]'   7.0               6.0  b'[6-8]'           b'[5-6]'
# 1               b'[3-5]'   7.0               5.0  b'[6-8]'           b'[5-6]'
# 2               b'[3-5]'   7.0               NaN  b'[6-8]'           b'[0-4]'
#
#    met decision decision_o match
# 0  0.0     b'1'       b'0'  b'0'
# 1  1.0     b'1'       b'0'  b'0'
# 2  1.0     b'1'       b'1'  b'1'

# %%
# We create a function that removes all the unwanted characters
def remove_xters(feature):
    return feature.replace("b'",'').replace("'","")
def remove_sqbrackets(feature):
    return feature.replace("[",'').replace("]","")

# We select string columns and apply the transformation
string_dataset = dating.select_dtypes(include = ['object'])

for feature in string_dataset.columns:
    dating[feature] = dating[feature].apply(lambda x: remove_xters(x))
    dating[feature] = dating[feature].apply(lambda x: remove_sqbrackets(x))

dating[string_dataset.columns].head(3)
# Out:
#   has_null  gender d_d_age                                   race  \
# 0           female     4-6  Asian/Pacific Islander/Asian-American
# 1           female     0-1  Asian/Pacific Islander/Asian-American
# 2           female     0-1  Asian/Pacific Islander/Asian-American
#
#                                   race_o samerace d_importance_same_race  \
# 0            European/Caucasian-American        0                    2-5
# 1            European/Caucasian-American        0                    2-5
# 2  Asian/Pacific Islander/Asian-American        1                    2-5
#
#   d_importance_same_religion field d_pref_o_attractive d_pref_o_sincere  \
# 0                        2-5   Law              21-100            16-20
# 1                        2-5   Law              21-100             0-15
# 2                        2-5   Law               16-20            16-20
#
#   d_pref_o_intelligence d_pref_o_funny d_pref_o_ambitious  \
# 0                 16-20          16-20               0-15
# 1                  0-15         21-100               0-15
# 2                 16-20          16-20               0-15
#
#   d_pref_o_shared_interests d_attractive_o d_sinsere_o d_intelligence_o  \
# 0                      0-15            6-8         6-8              6-8
# 1                      0-15            6-8         6-8             9-10
# 2                      0-15           9-10        9-10             9-10
#
#   d_funny_o d_ambitous_o d_shared_interests_o d_attractive_important  \
# 0       6-8          6-8                  6-8                   0-15
# 1       6-8          6-8                  0-5                   0-15
# 2      9-10         9-10                 9-10                   0-15
#
#   d_sincere_important d_intellicence_important d_funny_important  \
# 0               16-20                    16-20              0-15
# 1               16-20                    16-20              0-15
# 2               16-20                    16-20              0-15
#
#   d_ambtition_important d_shared_interests_important d_attractive d_sincere  \
# 0                  0-15                         0-15          6-8       6-8
# 1                  0-15                         0-15          6-8       6-8
# 2                  0-15                         0-15          6-8       6-8
#
#   d_intelligence d_funny d_ambition d_attractive_partner d_sincere_partner  \
# 0            6-8     6-8        6-8                  6-8              9-10
# 1            6-8     6-8        6-8                  6-8               6-8
# 2            6-8     6-8        6-8                  0-5               6-8
#
#   d_intelligence_partner d_funny_partner d_ambition_partner  \
# 0                    6-8             6-8                6-8
# 1                    6-8             6-8                0-5
# 2                   9-10             6-8                0-5
#
#   d_shared_interests_partner d_sports d_tvsports d_exercise d_dining  \
# 0                        0-5     9-10        0-5        6-8     9-10
# 1                        6-8     9-10        0-5        6-8     9-10
# 2                        6-8     9-10        0-5        6-8     9-10
#
#   d_museums d_art d_hiking d_gaming d_clubbing d_reading  d_tv d_theater  \
# 0       0-5   0-5      0-5      0-5        0-5       6-8  9-10       0-5
# 1       0-5   0-5      0-5      0-5        0-5       6-8  9-10       0-5
# 2       0-5   0-5      0-5      0-5        0-5       6-8  9-10       0-5
#
#   d_movies d_concerts d_music d_shopping d_yoga d_interests_correlate  \
# 0     9-10       9-10    9-10        6-8    0-5                0-0.33
# 1     9-10       9-10    9-10        6-8    0-5                0.33-1
# 2     9-10       9-10    9-10        6-8    0-5                0-0.33
#
#   d_expected_happy_with_sd_people d_expected_num_interested_in_me  \
# 0                             0-4                             0-3
# 1                             0-4                             0-3
# 2                             0-4                             0-3
#
#   d_expected_num_matches d_like d_guess_prob_liked decision decision_o match
# 0                    3-5    6-8                5-6        1          0     0
# 1                    3-5    6-8                5-6        1          0     0
# 2                    3-5    6-8                0-4        1          1     1

# %% [markdown]
# #### 4.3 Dropping missing data

# %% [markdown]
# ##### 4.3.1 remove in each row if that row contain missing value more than 5 columns

# %%
missing_values = dating.isnull().sum(axis=1)
threshold = 5
rows_with_too_many_missing_values = dating[missing_values > threshold]
num_rows_with_too_many_missing_values = len(rows_with_too_many_missing_values)
print("Sum of rows with too many missing values:", num_rows_with_too_many_missing_values)
# Out:
# Sum of rows with too many missing values: 475

# %%
dating = dating.dropna(thresh=dating.shape[1]-threshold)
num_missing = dating.isna().sum()
print(num_missing)
# Out:
# has_null                              0
# wave                                  0
# gender                                0
# age                                  25
# age_o                                25
# d_age                                 0
# d_d_age                               0
# race                                  0
# race_o                                0
# samerace                              0
# importance_same_race                  0
# importance_same_religion              0
# d_importance_same_race                0
# d_importance_same_religion            0
# field                                 0
# pref_o_attractive                     0
# pref_o_sincere                        0
# pref_o_intelligence                   0
# pref_o_funny                          9
# pref_o_ambitious                     17
# pref_o_shared_interests              37
# d_pref_o_attractive                   0
# d_pref_o_sincere                      0
# d_pref_o_intelligence                 0
# d_pref_o_funny                        0
# d_pref_o_ambitious                    0
# d_pref_o_shared_interests             0
# attractive_o                          9
# sinsere_o                            69
# intelligence_o                       83
# funny_o                             137
# ambitous_o                          485
# shared_interests_o                  826
# d_attractive_o                        0
# d_sinsere_o                           0
# d_intelligence_o                      0
# d_funny_o                             0
# d_ambitous_o                          0
# d_shared_interests_o                  0
# attractive_important                  0
# sincere_important                     0
# intellicence_important                0
# funny_important                       9
# ambtition_important                  18
# shared_interests_important           38
# d_attractive_important                0
# d_sincere_important                   0
# d_intellicence_important              0
# d_funny_important                     0
# d_ambtition_important                 0
# d_shared_interests_important          0
# attractive                            0
# sincere                               0
# intelligence                          0
# funny                                 0
# ambition                              0
# d_attractive                          0
# d_sincere                             0
# d_intelligence                        0
# d_funny                               0
# d_ambition                            0
# attractive_partner                    9
# sincere_partner                      65
# intelligence_partner                 87
# funny_partner                       135
# ambition_partner                    486
# shared_interests_partner            830
# d_attractive_partner                  0
# d_sincere_partner                     0
# d_intelligence_partner                0
# d_funny_partner                       0
# d_ambition_partner                    0
# d_shared_interests_partner            0
# sports                                0
# tvsports                              0
# exercise                              0
# dining                                0
# museums                               0
# art                                   0
# hiking                                0
# gaming                                0
# clubbing                              0
# reading                               0
# tv                                    0
# theater                               0
# movies                                0
# concerts                              0
# music                                 0
# shopping                              0
# yoga                                  0
# d_sports                              0
# d_tvsports                            0
# d_exercise                            0
# d_dining                              0
# d_museums                             0
# d_art                                 0
# d_hiking                              0
# d_gaming                              0
# d_clubbing                            0
# d_reading                             0
# d_tv                                  0
# d_theater                             0
# d_movies                              0
# d_concerts                            0
# d_music                               0
# d_shopping                            0
# d_yoga                                0
# interests_correlate                   0
# d_interests_correlate                 0
# expected_happy_with_sd_people        16
# expected_num_interested_in_me      6167
# expected_num_matches               1104
# d_expected_happy_with_sd_people       0
# d_expected_num_interested_in_me       0
# d_expected_num_matches                0
# like                                 38
# guess_prob_liked                    101
# d_like                                0
# d_guess_prob_liked                    0
# met                                 173
# decision                              0
# decision_o                            0
# match                                 0
# dtype: int64

# %%
### Visual representation of the missing data in the dataset
missingno.matrix(dating)
# Out:
# <AxesSubplot: >

# %% [markdown]
# Then we considered remove 'has null', 'wave' because these 2 column has no further purpose and meaning.
# and remove 'expected_num_interested_in_me' because it contain missing value more than 60% of total data in that column

# %%
# Drop the has_null and wave columns
dating.drop(['has_null','wave','expected_num_interested_in_me'], axis = 1, inplace= True)

# %% [markdown]
# ##### 4.3.2 Age
# There are four different columns for age and these are: age of individual, age of partner, age difference, and age group (where ages have been binned into categories). However the age difference column is not standardized since the difference is between the higher age and the lower age. We will standardize the difference by subtracting age between each individual and their partner. Since the direction of the difference matters, the column will have both positive and negative values. We will then drop the other age columns

# %% [markdown]
# 💡 Impute missing value for age

# %%
age_median = dating['age'].median()
print('Median of the age column:', age_median)

#Impute missing value
dating['age'].fillna(age_median, inplace=True)

#Check the imputation
missing_values_after_imputation = dating['age'].isnull().sum()
print('Number of missing values in the age column after imputation:', missing_values_after_imputation)
# Out:
# Median of the age column: 26.0
# Number of missing values in the age column after imputation: 0

# %%
# Create age difference column
dating['age_diff'] = dating['age'] - dating['age_o']

# Drop other age columns
dating.drop(['age','age_o', 'd_age', 'd_d_age'], axis = 1, inplace = True)

# %% [markdown]
# ##### 4.4 Imputing all missing value

# %%
#imputing remaining null values with median
null_counts_revised = dating.isnull().sum()

for column, null_count in null_counts_revised.items():
    if null_count > 0:
        print(f"{column}: {null_count}")
        median_value = dating[column].median()
        dating[column].fillna(median_value, inplace=True)
# Out:
# pref_o_funny: 9
# pref_o_ambitious: 17
# pref_o_shared_interests: 37
# attractive_o: 9
# sinsere_o: 69
# intelligence_o: 83
# funny_o: 137
# ambitous_o: 485
# shared_interests_o: 826
# funny_important: 9
# ambtition_important: 18
# shared_interests_important: 38
# attractive_partner: 9
# sincere_partner: 65
# intelligence_partner: 87
# funny_partner: 135
# ambition_partner: 486
# shared_interests_partner: 830
# expected_happy_with_sd_people: 16
# expected_num_matches: 1104
# like: 38
# guess_prob_liked: 101
# met: 173
# age_diff: 25

# %%
for column, null_count in null_counts_revised.items():
    if null_count == 0:
        print(f"{column}: {null_count}")
# Out:
# gender: 0
# race: 0
# race_o: 0
# samerace: 0
# importance_same_race: 0
# importance_same_religion: 0
# d_importance_same_race: 0
# d_importance_same_religion: 0
# field: 0
# pref_o_attractive: 0
# pref_o_sincere: 0
# pref_o_intelligence: 0
# d_pref_o_attractive: 0
# d_pref_o_sincere: 0
# d_pref_o_intelligence: 0
# d_pref_o_funny: 0
# d_pref_o_ambitious: 0
# d_pref_o_shared_interests: 0
# d_attractive_o: 0
# d_sinsere_o: 0
# d_intelligence_o: 0
# d_funny_o: 0
# d_ambitous_o: 0
# d_shared_interests_o: 0
# attractive_important: 0
# sincere_important: 0
# intellicence_important: 0
# d_attractive_important: 0
# d_sincere_important: 0
# d_intellicence_important: 0
# d_funny_important: 0
# d_ambtition_important: 0
# d_shared_interests_important: 0
# attractive: 0
# sincere: 0
# intelligence: 0
# funny: 0
# ambition: 0
# d_attractive: 0
# d_sincere: 0
# d_intelligence: 0
# d_funny: 0
# d_ambition: 0
# d_attractive_partner: 0
# d_sincere_partner: 0
# d_intelligence_partner: 0
# d_funny_partner: 0
# d_ambition_partner: 0
# d_shared_interests_partner: 0
# sports: 0
# tvsports: 0
# exercise: 0
# dining: 0
# museums: 0
# art: 0
# hiking: 0
# gaming: 0
# clubbing: 0
# reading: 0
# tv: 0
# theater: 0
# movies: 0
# concerts: 0
# music: 0
# shopping: 0
# yoga: 0
# d_sports: 0
# d_tvsports: 0
# d_exercise: 0
# d_dining: 0
# d_museums: 0
# d_art: 0
# d_hiking: 0
# d_gaming: 0
# d_clubbing: 0
# d_reading: 0
# d_tv: 0
# d_theater: 0
# d_movies: 0
# d_concerts: 0
# d_music: 0
# d_shopping: 0
# d_yoga: 0
# interests_correlate: 0
# d_interests_correlate: 0
# d_expected_happy_with_sd_people: 0
# d_expected_num_interested_in_me: 0
# d_expected_num_matches: 0
# d_like: 0
# d_guess_prob_liked: 0
# decision: 0
# decision_o: 0
# match: 0

# %% [markdown]
# ##### 4.4.1 Binned variables
# The speed dating dataset has some of the numeric features binned into categories. This is a duplication of information which increases the dimensionality of the dataset without adding any significant value. We will remove all the duplicated features. Conveniently, the names of these binned features have the prefix "d_". We will use this to subset and remove these features. Before the selection, the dataset has 117 features, and after the selection, we remain with 63 features.

# %%
dating.shape
# Out:
# (7903, 117)

# %%
to_drop = [column_name for column_name in dating.columns if column_name.startswith('d_')]
dating.drop(to_drop, axis = 1, inplace = True)
dating.shape
# Out:
# (7903, 63)

# %% [markdown]
# ##### 4.4.2 Field
# In the individual field indicating their careers, there's an overlapping of values. For instance, Business, which is the most popular field still comprises of MBA (2nd most popular), Finance, business [MBA] etc. Physics, Chemistry, Biology all fall under science. Due to this variation and overlapping, we will drop the column

# %%
display(dating.field.value_counts().head(30))
dating.drop('field',axis = 1, inplace = True)
# Out:
# Business                  493
# Law                       440
# MBA                       434
# Social Work               370
# International Affairs     245
# Electrical Engineering    154
# Psychology                126
# law                       118
# Finance                   112
# Mathematics                94
# Film                       90
# business                   90
# Sociology                  88
# Biology                    85
# Engineering                75
# Business MBA               75
# Biochemistry               67
# Political Science          67
# Clinical Psychology        66
# Economics                  65
# chemistry                  57
# Education                  55
# Operations Research        54
# Physics                    54
# School Psychology          52
# medicine                   51
# sociology                  50
# Urban Planning             48
# Mechanical Engineering     48
# English                    45
# Name: field, dtype: int64

# %% [markdown]
# ##### 4.4.3 Met
# The variable met answers the question as to whether the person has previously met the partner. Since the responses are either yes(1) or no (0), we will clean the column and change responses with neither values, and replace them with the most frequent value. Since they are only a few values, they will not skew our data.

# %%
print(f'Before \n{dating.met.value_counts()}')

for number in [3.0, 5.0, 6.0, 7.0, 8.0]:
    dating['met'].replace(number,0, inplace =True)
    
print(f'\nAfter \n{dating.met.value_counts()}')
# Out:
# Before
# 0.0    7560
# 1.0     336
# 7.0       3
# 5.0       2
# 3.0       1
# 8.0       1
# Name: met, dtype: int64
#
# After
# 0.0    7567
# 1.0     336
# Name: met, dtype: int64

# %% [markdown]
# ##### 4.4.4 Variables similar to the y variable
# The two variables 'decision' and 'decision_o' have similar responses almost similar to the variable being predicted. We will therefore remove these two features.

# %%
display(dating.groupby('decision')['match'].value_counts())
print()
display(dating.groupby('decision_o')['match'].value_counts())

dating.drop(['decision_o','decision'], axis = 1, inplace = True)
# Out:
# decision  match
# 0         0        4519
# 1         0        2050
#           1        1334
# Name: match, dtype: int64
# decision_o  match
# 0           0        4513
# 1           0        2056
#             1        1334
# Name: match, dtype: int64

# %% [markdown]
# #### 4.5 Encoding Feature

# %%
le = LabelEncoder()

# %%
def Encoder(df):
    columnsToEncode = list(df.select_dtypes(include=['category','object']))
    for feature in columnsToEncode:
      try:
          df[feature] = le.fit_transform(df[feature])
      except:
          print('Error encoding '+feature)
    return df

# %%
columnsToEncode = list(dating.select_dtypes(include=['category','object']))

# %%
for feature in columnsToEncode:
    try:
      dating[feature] = le.fit_transform(dating[feature])
    except:
      print('Error encoding '+feature)

# %%
dating_encode = Encoder(dating)

# %%
dating_encode.head()
# Out:
#    gender  race  race_o  samerace  importance_same_race  \
# 0       0     0       2         0                   2.0
# 1       0     0       2         0                   2.0
# 2       0     0       0         1                   2.0
# 3       0     0       2         0                   2.0
# 4       0     0       3         0                   2.0
#
#    importance_same_religion  pref_o_attractive  pref_o_sincere  \
# 0                       4.0               35.0            20.0
# 1                       4.0               60.0             0.0
# 2                       4.0               19.0            18.0
# 3                       4.0               30.0             5.0
# 4                       4.0               30.0            10.0
#
#    pref_o_intelligence  pref_o_funny  pref_o_ambitious  \
# 0                 20.0          20.0               0.0
# 1                  0.0          40.0               0.0
# 2                 19.0          18.0              14.0
# 3                 15.0          40.0               5.0
# 4                 20.0          10.0              10.0
#
#    pref_o_shared_interests  attractive_o  sinsere_o  intelligence_o  funny_o  \
# 0                      5.0           6.0        8.0             8.0      8.0
# 1                      0.0           7.0        8.0            10.0      7.0
# 2                     12.0          10.0       10.0            10.0     10.0
# 3                      5.0           7.0        8.0             9.0      8.0
# 4                     20.0           8.0        7.0             9.0      6.0
#
#    ambitous_o  shared_interests_o  attractive_important  sincere_important  \
# 0         8.0                 6.0                  15.0               20.0
# 1         7.0                 5.0                  15.0               20.0
# 2        10.0                10.0                  15.0               20.0
# 3         9.0                 8.0                  15.0               20.0
# 4         9.0                 7.0                  15.0               20.0
#
#    intellicence_important  funny_important  ambtition_important  \
# 0                    20.0             15.0                 15.0
# 1                    20.0             15.0                 15.0
# 2                    20.0             15.0                 15.0
# 3                    20.0             15.0                 15.0
# 4                    20.0             15.0                 15.0
#
#    shared_interests_important  attractive  sincere  intelligence  funny  \
# 0                        15.0         6.0      8.0           8.0    8.0
# 1                        15.0         6.0      8.0           8.0    8.0
# 2                        15.0         6.0      8.0           8.0    8.0
# 3                        15.0         6.0      8.0           8.0    8.0
# 4                        15.0         6.0      8.0           8.0    8.0
#
#    ambition  attractive_partner  sincere_partner  intelligence_partner  \
# 0       7.0                 6.0              9.0                   7.0
# 1       7.0                 7.0              8.0                   7.0
# 2       7.0                 5.0              8.0                   9.0
# 3       7.0                 7.0              6.0                   8.0
# 4       7.0                 5.0              6.0                   7.0
#
#    funny_partner  ambition_partner  shared_interests_partner  sports  \
# 0            7.0               6.0                       5.0     9.0
# 1            8.0               5.0                       6.0     9.0
# 2            8.0               5.0                       7.0     9.0
# 3            7.0               6.0                       8.0     9.0
# 4            7.0               6.0                       6.0     9.0
#
#    tvsports  exercise  dining  museums  art  hiking  gaming  clubbing  \
# 0       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
# 1       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
# 2       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
# 3       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
# 4       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
#
#    reading   tv  theater  movies  concerts  music  shopping  yoga  \
# 0      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
# 1      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
# 2      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
# 3      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
# 4      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
#
#    interests_correlate  expected_happy_with_sd_people  expected_num_matches  \
# 0                 0.14                            3.0                   4.0
# 1                 0.54                            3.0                   4.0
# 2                 0.16                            3.0                   4.0
# 3                 0.61                            3.0                   4.0
# 4                 0.21                            3.0                   4.0
#
#    like  guess_prob_liked  met  match  age_diff
# 0   7.0               6.0  0.0      0      -6.0
# 1   7.0               5.0  1.0      0      -1.0
# 2   7.0               5.0  1.0      1      -1.0
# 3   7.0               6.0  0.0      1      -2.0
# 4   6.0               6.0  0.0      1      -3.0

# %% [markdown]
# #### 5. Dealing with imbalanced data and Split data

# %%
# Plot the distribution of the target variable
sns.countplot(x=dating_encode['match'], palette=['skyblue','pink'])
plt.title("Target variable distribution")
plt.show()

# %%
X = dating_encode.drop('match', axis = 1)
y = dating_encode['match']

# %%
# Instantiate RandomUnderSampler
sampler = RandomUnderSampler(random_state=33)

# Perform undersampling on your feature and target data
X_resampled, y_resampled = sampler.fit_resample(X, y)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X_resampled, y_resampled, test_size=0.2, random_state=42)

# X is your feature data, y is your target data

# Print the counts of each class in the training set after undersampling
print("Training set class counts after undersampling: ", np.bincount(y_train))

# Print the counts of each class in the test set
print("Test set class counts: ", np.bincount(y_test))
# Out:
# Training set class counts after undersampling:  [1070 1064]
# Test set class counts:  [264 270]

# %%
# Plot the distribution of the target variable
sns.countplot(x=y_train, palette=['skyblue','pink'])
plt.title("Target variable: Train data distribution")
plt.show()

# %%
dating.head()
# Out:
#    gender  race  race_o  samerace  importance_same_race  \
# 0       0     0       2         0                   2.0
# 1       0     0       2         0                   2.0
# 2       0     0       0         1                   2.0
# 3       0     0       2         0                   2.0
# 4       0     0       3         0                   2.0
#
#    importance_same_religion  pref_o_attractive  pref_o_sincere  \
# 0                       4.0               35.0            20.0
# 1                       4.0               60.0             0.0
# 2                       4.0               19.0            18.0
# 3                       4.0               30.0             5.0
# 4                       4.0               30.0            10.0
#
#    pref_o_intelligence  pref_o_funny  pref_o_ambitious  \
# 0                 20.0          20.0               0.0
# 1                  0.0          40.0               0.0
# 2                 19.0          18.0              14.0
# 3                 15.0          40.0               5.0
# 4                 20.0          10.0              10.0
#
#    pref_o_shared_interests  attractive_o  sinsere_o  intelligence_o  funny_o  \
# 0                      5.0           6.0        8.0             8.0      8.0
# 1                      0.0           7.0        8.0            10.0      7.0
# 2                     12.0          10.0       10.0            10.0     10.0
# 3                      5.0           7.0        8.0             9.0      8.0
# 4                     20.0           8.0        7.0             9.0      6.0
#
#    ambitous_o  shared_interests_o  attractive_important  sincere_important  \
# 0         8.0                 6.0                  15.0               20.0
# 1         7.0                 5.0                  15.0               20.0
# 2        10.0                10.0                  15.0               20.0
# 3         9.0                 8.0                  15.0               20.0
# 4         9.0                 7.0                  15.0               20.0
#
#    intellicence_important  funny_important  ambtition_important  \
# 0                    20.0             15.0                 15.0
# 1                    20.0             15.0                 15.0
# 2                    20.0             15.0                 15.0
# 3                    20.0             15.0                 15.0
# 4                    20.0             15.0                 15.0
#
#    shared_interests_important  attractive  sincere  intelligence  funny  \
# 0                        15.0         6.0      8.0           8.0    8.0
# 1                        15.0         6.0      8.0           8.0    8.0
# 2                        15.0         6.0      8.0           8.0    8.0
# 3                        15.0         6.0      8.0           8.0    8.0
# 4                        15.0         6.0      8.0           8.0    8.0
#
#    ambition  attractive_partner  sincere_partner  intelligence_partner  \
# 0       7.0                 6.0              9.0                   7.0
# 1       7.0                 7.0              8.0                   7.0
# 2       7.0                 5.0              8.0                   9.0
# 3       7.0                 7.0              6.0                   8.0
# 4       7.0                 5.0              6.0                   7.0
#
#    funny_partner  ambition_partner  shared_interests_partner  sports  \
# 0            7.0               6.0                       5.0     9.0
# 1            8.0               5.0                       6.0     9.0
# 2            8.0               5.0                       7.0     9.0
# 3            7.0               6.0                       8.0     9.0
# 4            7.0               6.0                       6.0     9.0
#
#    tvsports  exercise  dining  museums  art  hiking  gaming  clubbing  \
# 0       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
# 1       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
# 2       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
# 3       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
# 4       2.0       8.0     9.0      1.0  1.0     5.0     1.0       5.0
#
#    reading   tv  theater  movies  concerts  music  shopping  yoga  \
# 0      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
# 1      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
# 2      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
# 3      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
# 4      6.0  9.0      1.0    10.0      10.0    9.0       8.0   1.0
#
#    interests_correlate  expected_happy_with_sd_people  expected_num_matches  \
# 0                 0.14                            3.0                   4.0
# 1                 0.54                            3.0                   4.0
# 2                 0.16                            3.0                   4.0
# 3                 0.61                            3.0                   4.0
# 4                 0.21                            3.0                   4.0
#
#    like  guess_prob_liked  met  match  age_diff
# 0   7.0               6.0  0.0      0      -6.0
# 1   7.0               5.0  1.0      0      -1.0
# 2   7.0               5.0  1.0      1      -1.0
# 3   7.0               6.0  0.0      1      -2.0
# 4   6.0               6.0  0.0      1      -3.0

# %% [markdown]
# ### 6. Model evaluation before dimension reduction
# We train and evaluate our models before we begin dimension reduction to find the accuracy when we use all the features. We will use the xgboost classifier for our evaluation since it has the highest accuracy of 0.875. This will therefore be the base value with which we will compare the accuracy of our model after dimension reduction

# %%
# We instantiate different models to test their accuracy
logreg = LogisticRegression(max_iter = 10000)
svc = SVC()
knn = KNeighborsClassifier()
rf = RandomForestClassifier()
xg_cl = xgb.XGBClassifier()

classifiers = [('logreg',logreg),('svc',svc),('knn',knn),('random forest',rf),('xgboost',xg_cl)]

# We fit the different models and compute the accuracy
for clf_name, model in classifiers:
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
    print(clf_name, accuracy)
# Out:
# logreg 0.7734082397003745
# svc 0.7771535580524345
# knn 0.6385767790262172
# random forest 0.7602996254681648
# xgboost 0.7790262172284644

# %% [markdown]
# ### 7. Dimension reduction

# %% [markdown]
# #### 7.1 Feature selection with Random forests
# Random forest classifiers have a feature importances attribute that shows the contribution of each feature to the model.

# %%
rf = RandomForestClassifier(random_state=42)

# Fit the classifier
rf.fit(X_train, y_train)

# Retrieve the feature importances
rf_importance = pd.Series(rf.feature_importances_, index = rf.feature_names_in_)
rf_importance = rf_importance.sort_values(ascending = False)
rf_importance.head()
# Out:
# funny_o               0.055829
# like                  0.052967
# attractive_o          0.051860
# attractive_partner    0.046229
# shared_interests_o    0.040124
# dtype: float64

# %% [markdown]
# #### The top most important ***5*** features according to the random forest classifier are:
# 1.Rating on your partner being **funny**
# 2.Whether they **like** their partner
# 3.Rating by partner (about me) on **attractiveness**
# 4.Rating on your partner being **attractiveness**
# 5. Rating by partner (about me) on **shared interest**

# %%
# Visualizing the feature importances
fig = plt.figure(figsize = (10,12))
rf_importance.sort_values(ascending = True).plot(kind = 'barh', width =0.8)
plt.tight_layout()
plt.show()

# %%
fig = plt.figure(figsize = (12,8))
rf_importance_sorted = rf_importance.sort_values(ascending = True)
top_features = rf_importance_sorted[-5:]
colors = ['royalblue', 'dodgerblue', 'lightskyblue', 'paleturquoise', 'powderblue']
top_features.plot(kind = 'barh', width = 0.6, color = colors)
plt.tight_layout()
plt.show()

# %% [markdown]
# We zoomed in to see the last 3 feature that tend not to play the important role

# %%
fig = plt.figure(figsize = (12,8))
rf_importance_sorted = rf_importance.sort_values(ascending = True)
top_features = rf_importance_sorted[:3]
colors = ['sandybrown','lightsalmon',  'wheat']
top_features.plot(kind = 'barh', width = 0.6, color = colors)
plt.tight_layout()
plt.show()

# %% [markdown]
# The feature importance values of random forests are in percentage. Therefore, we can try and select features with a contribution of more than 1% and see if removing the features reduces noise, thus improving our model accuracy.

# %%
# Selecting features 
top_features = rf_importance[rf_importance>0.01].index

# Create a random forest classifier
rf_cl = RandomForestClassifier()

# Fit the model
rf_cl.fit(X_train[top_features], y_train)

# Make predictions
y_pred = rf_cl.predict(X_test[top_features])
accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
print(f'Dropping features from {len(rf_importance)} to {len(top_features)} give an accuracy of {accuracy}')
# Out:
# Dropping features from 59 to 49 give an accuracy of 0.7808988764044944

# %% [markdown]
# #### 7.2 Feature selection with XGbooster
# Xgboost is used in feature selection by outputting feature importance values from a trained model. To leverage the performance and efficiency of the algorithm, the dataset is converted to a DMatrix format which is used for training.
# The top most important features according to the xgboost classifier are:
# 1. Rating by partner (about me) on**attractiveness**
# 2. Rating of how you think your partner **likes** you?
# 3. Rating on your partner **shared interest**
# 4. How many matches do you expect to get?
# 5. Whether they **like** their partner
#
#
# 💡 Xgboost has the .plot_importance() method that is used to visualize the importance values of all features in a plot.

# %%
# Convert the data to dmatrix
dating_matrix = xgb.DMatrix(data = X_train, label = y_train)
params = {'objective':'binary:logistic'}

# Train data using dmatrix format
xgb_clf = xgb.train(dtrain = dating_matrix, params = params, num_boost_round = 10)

# Plot the feature importances
fig, ax  = plt.subplots(figsize = (13,16))
xgb.plot_importance(xgb_clf, ax = ax)
plt.show()

# %% [markdown]
# In xgboost, the scores of each feature can be retrieved using the .get_score() method

# %%
xgb_features = pd.DataFrame(xgb_clf.get_score(), index = ['score']).T
xgb_features['score'].sort_values(ascending=False).head(8)
# Out:
# attractive_o            32.0
# guess_prob_liked        22.0
# shared_interests_o      18.0
# expected_num_matches    17.0
# like                    16.0
# pref_o_intelligence     16.0
# attractive_partner      15.0
# attractive_important    14.0
# Name: score, dtype: float64

# %% [markdown]
# We will evaluate the accuracy of the model with features with a score greater than 3. This selects 45 features which does not greatly affect our accuracy.

# %%
xgb_cl = xgb.XGBClassifier()

# Selecting features
xgb_top_features = xgb_features[xgb_features['score'] > 3].index

# Fit and predict
xgb_cl.fit(X_train[xgb_top_features],y_train)
y_pred = xgb_cl.predict(X_test[xgb_top_features])
accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
print(f'Dropping features from {len(xgb_features)} to {len(xgb_top_features)} results in an accuracy of {accuracy}')
# Out:
# Dropping features from 58 to 45 results in an accuracy of 0.7659176029962547

# %%
xgb_cl = xgb.XGBClassifier()

# Selecting features
xgb_top_features = xgb_features[xgb_features['score'] > 4].index

# Fit and predict
xgb_cl.fit(X_train[xgb_top_features],y_train)
y_pred = xgb_cl.predict(X_test[xgb_top_features])
accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
print(f'Dropping features from {len(xgb_features)} to {len(xgb_top_features)} results in an accuracy of {accuracy}')
# Out:
# Dropping features from 58 to 38 results in an accuracy of 0.7715355805243446

# %% [markdown]
# #### 7.4 Dimension reduction with Recursive Feature Elimination - RFE
# RFE is feature selection algorithm that produces feature importances or feature coeffients when a model is passed to it. It fits the model and drops the weakest features, and repeats the process until the specified number of features is attained. Using xgboost classifier, we test the accuracy of different number of features As seen below,
# In essence, if you are more concerned with what features play an important role in your prediction, the automatic selection of features by the recursive feature elimination method is very effective. In this circumstance, it's a tradeoff between dimensionality and accuracy.

# %%
from sklearn.feature_selection import RFE

xgb_cl = xgb.XGBClassifier()
for features in list(range(60,1,-5)):
    # Instantiate and fit the RFE
    rfe = RFE(estimator = xgb_cl, n_features_to_select = features)
    rfe.fit(X_train,y_train)
    
    # Make predictions
    y_pred = rfe.predict(X_test)
    accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
    print(f'The accuracy of {features} features is {accuracy}')
# Out:
# The accuracy of 60 features is 0.7790262172284644
# The accuracy of 55 features is 0.7528089887640449
# The accuracy of 50 features is 0.7453183520599251
# The accuracy of 45 features is 0.7490636704119851
# The accuracy of 40 features is 0.7715355805243446
# The accuracy of 35 features is 0.7846441947565543
# The accuracy of 30 features is 0.7528089887640449
# The accuracy of 25 features is 0.7677902621722846
# The accuracy of 20 features is 0.7790262172284644
# The accuracy of 15 features is 0.7621722846441947
# The accuracy of 10 features is 0.7546816479400749
# The accuracy of 5 features is 0.7378277153558053

# %% [markdown]
# ##### 7.4.1 Selecting the features

# %% [markdown]
# Suppose we want a balance between dimensionality of the dataset and the accuracy,
# we can select 20 features whose accuracy is 0.7790.
# The .support_ attribute is used to give a mask with True and False values for features selected and those not selected respectively.

# %%
xgb_cl = xgb.XGBClassifier()

# Instatiate RFE with 20 features
rfe = RFE(estimator = xgb.XGBClassifier(), n_features_to_select = 20)

# Fit and predict
rfe.fit(X_train,y_train)
y_pred = rfe.predict(X_test)
accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
print(f'Model accuracy is {accuracy}')
# Out:
# Model accuracy is 0.7790262172284644

# %%
# Select a mask with features selected
mask = rfe.support_
xgb_all_features = X_train.columns.tolist()

# Print all features with new line
print('\nAll features in the dataset:')
for feature in xgb_all_features:
    print(feature)
# Out:
# All features in the dataset:
# gender
# race
# race_o
# samerace
# importance_same_race
# importance_same_religion
# pref_o_attractive
# pref_o_sincere
# pref_o_intelligence
# pref_o_funny
# pref_o_ambitious
# pref_o_shared_interests
# attractive_o
# sinsere_o
# intelligence_o
# funny_o
# ambitous_o
# shared_interests_o
# attractive_important
# sincere_important
# intellicence_important
# funny_important
# ambtition_important
# shared_interests_important
# attractive
# sincere
# intelligence
# funny
# ambition
# attractive_partner
# sincere_partner
# intelligence_partner
# funny_partner
# ambition_partner
# shared_interests_partner
# sports
# tvsports
# exercise
# dining
# museums
# art
# hiking
# gaming
# clubbing
# reading
# tv
# theater
# movies
# concerts
# music
# shopping
# yoga
# interests_correlate
# expected_happy_with_sd_people
# expected_num_matches
# like
# guess_prob_liked
# met
# age_diff

# %%
# Print selected features with new line
print(f'\nTop 20 features in the xgb classifier are:')
selected_features = np.array(xgb_all_features)[mask].tolist()
for feature in selected_features:
    print(feature)
# Out:
# Top 20 features in the xgb classifier are:
# pref_o_intelligence
# attractive_o
# funny_o
# shared_interests_o
# attractive_important
# sincere_important
# intellicence_important
# attractive
# intelligence
# funny
# attractive_partner
# funny_partner
# shared_interests_partner
# sports
# exercise
# shopping
# expected_num_matches
# like
# guess_prob_liked
# met

# %% [markdown]
# ##### 7.5 Combining features from different models
# You can use different models and choose features with selected by all the models, and then use these features for prediction.
# We will select the top 35 features in three models and select common features

# %% [markdown]
# ##### Selecting random forest features

# %%
rf = RandomForestClassifier(random_state= 33 )

rfe = RFE(estimator = rf, n_features_to_select = 35)
rfe.fit(X_train,y_train)
y_pred = rfe.predict(X_test)
accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
print(f'Model accuracy is {accuracy}')

mask_rfe = rfe.support_
# Out:
# Model accuracy is 0.7677902621722846

# %% [markdown]
# ##### Selecting Logistic Regression features

# %%
logreg = LogisticRegression(max_iter =100000)

rfe = RFE(estimator = logreg, n_features_to_select = 35)
rfe.fit(X_train,y_train)
y_pred = rfe.predict(X_test)
accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
print(f'Model accuracy is {accuracy}')

mask_log = rfe.support_
# Out:
# Model accuracy is 0.7771535580524345

# %% [markdown]
# ##### Selecting XGbooster features

# %%
xgb_cl = xgb.XGBClassifier()

rfe = RFE(estimator = xgb_cl, n_features_to_select = 35)
rfe.fit(X_train,y_train)
y_pred = rfe.predict(X_test)
accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
print(f'Model accuracy is {accuracy}')

mask_xgb = rfe.support_
# Out:
# Model accuracy is 0.7846441947565543

# %% [markdown]
# ##### 7.5.1 Evaluating features selected by the three classifiers
# After selecting 35 features in all our models,
# we will combine them to select features chosen by all the models.
# We will use these features for our prediction.
# #### "How many total features were present in all the models?"

# %%
# Find sum of mask to identify common features 
mask_all_models = np.sum([mask_rfe, mask_log,mask_xgb], axis=0)

# Select features selected by all the three models
mask = mask_all_models == 3
most_important_features = X_train.columns[mask]

print(most_important_features.shape)
print()
print(most_important_features)
# Out:
# (14,)
#
# Index(['attractive_o', 'sinsere_o', 'funny_o', 'shared_interests_o',
#        'attractive_partner', 'funny_partner', 'shared_interests_partner',
#        'sports', 'exercise', 'tv', 'shopping', 'expected_num_matches', 'like',
#        'guess_prob_liked'],
#       dtype='object')

# %%
xg_cl = xgb.XGBClassifier()

xg_cl.fit(X_train[most_important_features], y_train)
y_pred = xg_cl.predict(X_test[most_important_features])
accuracy = (np.sum(y_pred == y_test))/(len(y_pred))
print(f'Accuracy of 14 features selected by all models is {accuracy}')
# Out:
# Accuracy of 14 features selected by all models is 0.7359550561797753

# %% [markdown]
# ##### When the 14 features selected by the three models are evaluated, they give an accuracy of 0.7359 with xgboost.

# %% [markdown]
# ### สมาชิก กลุ่มที่ 8
# 6342001426 กฤตภาส โฆษิตชุติมา
# 6342050126 ธัญจิรา ตันติวิภานุวงศ์
# 6342071326 พัทธนันท์ ฝอยทอง
# 6342008926 ขนิฐฐา ชื่นชัชวาลย์
# 6342017526 ชวิณี พลอยสุวรรณ
